# %% [markdown]
# <a href="https://colab.research.google.com/github/soloo4040/machine-learning-/blob/main/machinelearning0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Load Data**

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/mosh-hamedani/python-supplementary-materials/refs/heads/main/music.csv')
df
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %% [markdown]
# #**Data Preparation**

# %% [markdown]
# ##**Data separation as X and y**

# %%
y = df['genre']
y
# Out:
# 0        HipHop
# 1        HipHop
# 2        HipHop
# 3          Jazz
# 4          Jazz
# 5          Jazz
# 6     Classical
# 7     Classical
# 8     Classical
# 9         Dance
# 10        Dance
# 11        Dance
# 12     Acoustic
# 13     Acoustic
# 14     Acoustic
# 15    Classical
# 16    Classical
# 17    Classical
# Name: genre, dtype: object

# %%
X = df.drop(columns=['genre'])
X
# Out:
#     age  gender
# 0    20       1
# 1    23       1
# 2    25       1
# 3    26       1
# 4    29       1
# 5    30       1
# 6    31       1
# 7    33       1
# 8    37       1
# 9    20       0
# 10   21       0
# 11   25       0
# 12   26       0
# 13   27       0
# 14   30       0
# 15   31       0
# 16   34       0
# 17   35       0

# %% [markdown]
# ##**Data Splitting**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#     age  gender
# 8    37       1
# 15   31       0
# 14   30       0
# 4    29       1
# 3    26       1
# 0    20       1
# 2    25       1
# 10   21       0
# 5    30       1
# 9    20       0
# 1    23       1
# 13   27       0
# 17   35       0
# 7    33       1

# %%
X_test
# Out:
#     age  gender
# 6    31       1
# 12   26       0
# 16   34       0
# 11   25       0

# %% [markdown]
# #**Model Building**

# %% [markdown]
# ##**DecisionTreeClassifier**

# %% [markdown]
# Training the model

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Making predictions

# %%
y_model_train_pred = model.predict(X_train)
y_model_test_pred = model.predict(X_test)
y_model_train_pred
# Out:
# array(['Classical', 'Acoustic', 'Classical', 'Acoustic', 'Dance', 'Jazz',
#        'Classical', 'Classical', 'Dance', 'HipHop', 'Jazz', 'Classical',
#        'Dance', 'Classical'], dtype=object)

# %%
y_model_test_pred
# Out:
# array(['HipHop', 'Jazz', 'HipHop', 'Acoustic'], dtype=object)

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test,y_model_test_pred)
score
# Out:
# 1.0
